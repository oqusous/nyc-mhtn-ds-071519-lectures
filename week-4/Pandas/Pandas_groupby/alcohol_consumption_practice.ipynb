# %% [markdown]
# # GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarizes as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %%
pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks and look at the first 10 rows of the DF.

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')

drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.groupby('continent')['beer_servings'].sum()
# Out:
# continent
# AF    3258
# AS    1630
# EU    8720
# OC    1435
# SA    2101
# Name: beer_servings, dtype: int64

# %% [markdown]
# ### Step 5. For each continent print the summary statistics for wine consumption.

# %%
drinks.groupby('continent')['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Step 6. Print the mean alcoohol consumption per continent for every column

# %%
drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcoohol consumption per continent for every column

# %%
drinks.groupby('continent').median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.

# %%
drinks.groupby('continent')['spirit_servings'].aggregate(['mean','min','max'])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302

# %% [markdown]
# ### Step 9. Print the mean, min and max values for beer consumption and the mean and std deviation for wine consumption.

# %%
drinks.groupby('continent').aggregate({'beer_servings': ['min','max', 'mean'],'wine_servings': ['mean','std']})
# Out:
#           beer_servings                  wine_servings
#                     min  max        mean          mean        std
# continent
# AF                    0  376   61.471698     16.264151  38.846419
# AS                    0  247   37.045455      9.068182  21.667034
# EU                    0  361  193.777778    142.222222  97.421738
# OC                    0  306   89.687500     35.625000  64.555790
# SA                   93  333  175.083333     62.416667  88.620189

# %% [markdown]
# ### Step 10.  Create a custom aggregation function and apply it to some of the columns

# %%
drinks.groupby('continent').aggregate({'spirit_servings': ['min','max', 'mean'],'wine_servings': ['mean','std']})
# Out:
#           spirit_servings                  wine_servings
#                       min  max        mean          mean        std
# continent
# AF                      0  152   16.339623     16.264151  38.846419
# AS                      0  326   60.840909      9.068182  21.667034
# EU                      0  373  132.555556    142.222222  97.421738
# OC                      0  254   58.437500     35.625000  64.555790
# SA                     25  302  114.750000     62.416667  88.620189

# %%
drinks.loc[drinks['beer_servings'] > 300, ['beer_servings', 'country']]
# Out:
#      beer_servings         country
# 45             361  Czech Republic
# 62             347           Gabon
# 65             346         Germany
# 81             313         Ireland
# 98             343       Lithuania
# 117            376         Namibia
# 129            306           Palau
# 135            343          Poland
# 188            333       Venezuela

# %%
drinks.loc[drinks['wine_servings'] > 200, ['wine_servings', 'country']]
# Out:
#      wine_servings            country
# 3              312            Andorra
# 6              221          Argentina
# 8              212          Australia
# 16             212            Belgium
# 42             254            Croatia
# 48             278            Denmark
# 55             233  Equatorial Guinea
# 61             370             France
# 67             218             Greece
# 83             237              Italy
# 99             271         Luxembourg
# 136            339           Portugal
# 156            276           Slovenia
# 166            280        Switzerland
# 185            220            Uruguay

# %%
drinks.loc[drinks['spirit_servings'] > 250, ['spirit_servings', 'country']]
# Out:
#      spirit_servings             country
# 15               373             Belarus
# 25               252            Bulgaria
# 40               254        Cook Islands
# 50               286            Dominica
# 68               438             Grenada
# 72               302              Guyana
# 73               326               Haiti
# 141              326  Russian Federation
# 144              315           St. Lucia
# 155              293            Slovakia
# 169              258            Thailand

# %%
drinks.loc[drinks['total_litres_of_pure_alcohol'] > 10.5, ['total_litres_of_pure_alcohol', 'country']]
# Out:
#      total_litres_of_pure_alcohol             country
# 3                            12.4             Andorra
# 15                           14.4             Belarus
# 45                           11.8      Czech Republic
# 61                           11.8              France
# 65                           11.3             Germany
# 68                           11.9             Grenada
# 75                           11.3             Hungary
# 81                           11.4             Ireland
# 98                           12.9           Lithuania
# 99                           11.4          Luxembourg
# 135                          10.9              Poland
# 136                          11.0            Portugal
# 141                          11.5  Russian Federation
# 155                          11.4            Slovakia
# 156                          10.6            Slovenia

# %%
drinks.loc[drinks['total_litres_of_pure_alcohol'] < 1, ['total_litres_of_pure_alcohol', 'country']]
# Out:
#      total_litres_of_pure_alcohol           country
# 0                             0.0       Afghanistan
# 2                             0.7           Algeria
# 13                            0.0        Bangladesh
# 19                            0.4            Bhutan
# 24                            0.6            Brunei
# 34                            0.4              Chad
# 38                            0.1           Comoros
# 46                            0.0       North Korea
# 53                            0.2             Egypt
# 56                            0.5           Eritrea
# 58                            0.7          Ethiopia
# 70                            0.2            Guinea
# 78                            0.1         Indonesia
# 79                            0.0              Iran
# 80                            0.2              Iraq
# 86                            0.5            Jordan
# 90                            0.0            Kuwait
# ...
